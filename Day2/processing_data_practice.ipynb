# %%
import pandas as pd

# %% [markdown]
# Encoding

# %%
from sklearn.preprocessing import LabelEncoder

encoded_data=df.copy()

one_hot_encoded = pd.get_dummies(encoded_data['Education'], prefix='Education')
encoded_data = pd.concat([encoded_data, one_hot_encoded], axis=1)

# Since 'Pclass' is ordinal, we can create a mapped column for demonstration.
education_mapping = {1: 'Masters', 2: 'Bachelors', 3: 'phD'}
# 3. Ordinal Encoding For p class
encoded_data['education_Category'] = encoded_data['Education'].map(education_mapping)

# Display the resulting dataset with relevant encoded columns
print(encoded_data[['Gender', 'Department', 'Education', 'Education_Masters', 'Education_Bachelors', 'Education_PhD', 'City']].head())
# Out:
#    Gender Department  Education  Education_Masters  Education_Bachelors  \
# 0    Male         HR    Masters               True                False
# 1  Female  Marketing  Bachelors              False                 True
# 2  Female         HR        NaN              False                False
# 3  Female         HR        PhD              False                False
# 4    Male         IT  Bachelors              False                 True
#
#    Education_PhD        City
# 0          False     Calicut
# 1          False     Chennai
# 2          False       Kochi
# 3           True  Trivandrum
# 4          False  Trivandrum

# %% [markdown]
# Scaling

# %%
titanic_data=pd.read_csv("/content/preprocessing_practice_dataset.csv")


#nnumerical columns
numerical_col=['Age','Experience_Years','Performance_Rating']

#drop rows with missing values
titanic_data.dropna(subset=numerical_col,inplace=True)

#initilize scalers
minmax_scaler=MinMaxScaler()
standard_scaler=StandardScaler()
robust_scaler=RobustScaler()


#applying minmax scaling
titanic_data['Age_minmax']=minmax_scaler.fit_transform(titanic_data[['Age']])
titanic_data['Experience_Years_minmax']=minmax_scaler.fit_transform(titanic_data[['Experience_Years']])


#apply standard scaling

titanic_data['Age_standard']=standard_scaler.fit_transform(titanic_data[['Age']])
titanic_data['Experience_Years_standard']=standard_scaler.fit_transform(titanic_data[['Experience_Years']])


#apply robust scaling

titanic_data['Age_robust']=robust_scaler.fit_transform(titanic_data[['Age']])
titanic_data['Experience_Years_robust']=robust_scaler.fit_transform(titanic_data[['Experience_Years']])
titanic_data[['Age','Age_minmax','Experience_Years_minmax','Age_standard','Experience_Years_standard','Age_robust','Experience_Years_standard']]
# Out:
#      Age  Age_minmax  Experience_Years_minmax  Age_standard  \
# 0   59.0    1.000000                 0.947368      1.746756
# 1   49.0    0.736842                 0.842105      0.833817
# 2   35.0    0.368421                 1.000000     -0.444297
# 3   28.0    0.184211                 0.473684     -1.083354
# 4   41.0    0.526316                 0.263158      0.103466
# ..   ...         ...                      ...           ...
# 95  54.0    0.868421                 0.578947      1.290286
# 96  53.0    0.842105                 0.684211      1.198993
# 97  43.0    0.578947                 0.052632      0.286054
# 98  44.0    0.605263                 0.947368      0.377348
# 99  57.0    0.947368                 0.894737      1.564168
#
#     Experience_Years_standard  Age_robust  Experience_Years_standard
# 0                    1.419878    0.960000                   1.419878
# 1                    1.097585    0.426667                   1.097585
# 2                    1.581024   -0.320000                   1.581024
# 3                   -0.030439   -0.693333                  -0.030439
# 4                   -0.675024    0.000000                  -0.675024
# ..                        ...         ...                        ...
# 95                   0.291854    0.693333                   0.291854
# 96                   0.614146    0.640000                   0.614146
# 97                  -1.319609    0.106667                  -1.319609
# 98                   1.419878    0.160000                   1.419878
# 99                   1.258731    0.853333                   1.258731
#
# [90 rows x 7 columns]

# %% [markdown]
# Visualization

# %%
import matplotlib.pyplot as plt
dd=pd.read_csv("/content/preprocessing_practice_dataset.csv")
sns.set(style="dark")

plt.figure(figsize=(18,8))

sns.lineplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
#set plot title and label

plt.title('Line plot of age by experience_years',fontsize=15)
plt.xlabel('Age',fontsize=12)
plt.ylabel('Experience_years',fontsize=12)
# Out:
# /tmp/ipykernel_674/3231626652.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
# Text(0, 0.5, 'Experience_years')

# %%
import matplotlib.pyplot as plt
dd=pd.read_csv("/content/preprocessing_practice_dataset.csv")
sns.set(style="dark")

plt.figure(figsize=(18,8))

sns.boxplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
#set plot title and label

plt.title('Box plot of age by experience_years',fontsize=15)
plt.xlabel('Age',fontsize=12)
plt.ylabel('Experience_years',fontsize=12)
# Out:
# /tmp/ipykernel_674/231205264.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
# Text(0, 0.5, 'Experience_years')

# %%
import matplotlib.pyplot as plt
dd=pd.read_csv("/content/preprocessing_practice_dataset.csv")
sns.set(style="dark")

plt.figure(figsize=(18,8))

sns.barplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
#set plot title and label

plt.title('Bar plot of age by experience_years',fontsize=15)
plt.xlabel('Age',fontsize=12)
plt.ylabel('Experience_years',fontsize=12)
# Out:
# /tmp/ipykernel_674/3836825954.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
# Text(0, 0.5, 'Experience_years')

# %%
import matplotlib.pyplot as plt
dd=pd.read_csv("/content/preprocessing_practice_dataset.csv")
sns.set(style="dark")

plt.figure(figsize=(18,8))

sns.histplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
#set plot title and label

plt.title('Histogram plot of age by experience_years',fontsize=15)
plt.xlabel('Age',fontsize=12)
plt.ylabel('Experience_years',fontsize=12)
# Out:
# /tmp/ipykernel_674/2538897896.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
# Text(0, 0.5, 'Experience_years')

# %%
import matplotlib.pyplot as plt
dd=pd.read_csv("/content/preprocessing_practice_dataset.csv")
sns.set(style="dark")

plt.figure(figsize=(18,8))

sns.scatterplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
#set plot title and label

plt.title('Scatter plot of age by experience_years',fontsize=15)
plt.xlabel('Age',fontsize=12)
plt.ylabel('Experience_years',fontsize=12)
# Out:
# /tmp/ipykernel_674/3583264984.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
# Text(0, 0.5, 'Experience_years')
